# %% [markdown]
# ## Model Training: Vision Transformer

# %% [markdown]
# ### Environment setup

# %%
import torch
from transformers import ViTForImageClassification, ViTFeatureExtractor
from torch.utils.data import DataLoader
from torchvision import transforms

# %% [markdown]
# ### Load pretrained vision transformer model and feature extractor

# %%
# Load pretrained ViT model and feature extractor
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k', num_labels=2)
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')

# %% [markdown]
# ### Dataset preparation

# %%
# Prepare the dataset (assuming images are stored in a directory and labeled)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])
